# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
#%matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
plt.plot(x, y, linewidth = 0.5)
plt.plot(x, z, linewidth = 0.5)

plt.xlabel('x') 
plt.ylabel('y') 

plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].plot(x,y)
axs[1].plot(x,z)

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
plt.plot(x, y, label='x-y', linewidth = 1.5)
plt.plot(x, z, label='x-z', linewidth = 1.5)

plt.xlabel('x') 
plt.ylabel('y') 

plt.title('Plot')
plt.legend()

plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
x = np.arange(1,100)
y = np.log(x) 
z = x**2

plt.plot(x, y, linewidth = 0.5)
plt.plot(x, z, linewidth = 0.5)

plt.xlabel('x') 
plt.ylabel('y') 

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# 5    2015-05-13             276    779      5.79      15            726.000
# 6    2015-05-14            2687   5614      4.17       2            782.000
# 7    2015-05-15            2793   8169      6.07      14            801.000
# 8    2015-05-16            4061  19971     14.84      18            532.000
# 9    2015-05-17            3349    852      6.33      12            606.000
# 10   2015-05-18            2961  11998      8.91      20            936.000
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# How the average number of steps change by month.
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
fitbit['Months_encoded'].hist().margins(0)

# Is Fitbitter more active on weekend or workdays?
# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

ax = sns.barplot(x="Days", y="Steps", data=fitbit)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
fig,axs = plt.subplots(1,3,figsize = (15,5))
activities = ['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']
for x,y in zip(range(len(activities)),activities):
    axs[x].scatter(fitbit['Steps'],fitbit[y])

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('titanic.csv')
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# 5               6       0.0       3
# 6               7       0.0       1
# 7               8       0.0       3
# 8               9       1.0       3
# 9              10       1.0       2
# 10             11       1.0       3
# 11             12       1.0       1
# 12             13       0.0       3
# 13             14       0.0       3
# 14             15       0.0       3
# 15             16       1.0       2
# 16             17       0.0       3
# 17             18       1.0       2
# 18             19       0.0       3
# 19             20       1.0       3
# 20             21       0.0       2
# 21             22       1.0       2
# 22             23       1.0       3
# 23             24       1.0       1
# 24             25       0.0       3
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
titanic.select_dtypes(include=['int64'])
# Out:
#       PassengerId  Pclass  SibSp  Parch
# 0               1       3      1      0
# 1               2       1      1      0
# 2               3       3      0      0
# 3               4       1      1      0
# 4               5       3      0      0
# 5               6       3      0      0
# 6               7       1      0      0
# 7               8       3      3      1
# 8               9       3      0      2
# 9              10       2      1      0
# 10             11       3      1      1
# 11             12       1      0      0
# 12             13       3      0      0
# 13             14       3      1      5
# 14             15       3      0      0
# 15             16       2      0      0
# 16             17       3      4      1
# 17             18       2      0      0
# 18             19       3      1      0
# 19             20       3      0      0
# 20             21       2      0      0
# 21             22       2      0      0
# ...

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(include=['float64'])
# Out:
#       Survived        Age      Fare
# 0          0.0  22.000000    7.2500
# 1          1.0  38.000000   71.2833
# 2          1.0  26.000000    7.9250
# 3          1.0  35.000000   53.1000
# 4          0.0  35.000000    8.0500
# 5          0.0  23.926502    8.4583
# 6          0.0  54.000000   51.8625
# 7          0.0   2.000000   21.0750
# 8          1.0  27.000000   11.1333
# 9          1.0  14.000000   30.0708
# 10         1.0   4.000000   16.7000
# 11         1.0  58.000000   26.5500
# 12         0.0  20.000000    8.0500
# 13         0.0  39.000000   31.2750
# 14         0.0  14.000000    7.8542
# 15         1.0  55.000000   16.0000
# 16         0.0   2.000000   29.1250
# 17         1.0  32.172868   13.0000
# 18         0.0  31.000000   18.0000
# 19         1.0  27.749836    7.2250
# 20         0.0  35.000000   26.0000
# 21         1.0  34.000000   13.0000
# 22         1.0  15.000000    8.0292
# 23         1.0  28.000000   35.5000
# 24         0.0   8.000000   21.0750
# ...

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(include=['object'])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# 5                                      Moran, Mr. James    male
# 6                               McCarthy, Mr. Timothy J    male
# 7                        Palsson, Master. Gosta Leonard    male
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                   Nasser, Mrs. Nicholas (Adele Achem)  female
# 10                      Sandstrom, Miss. Marguerite Rut  female
# 11                             Bonnell, Miss. Elizabeth  female
# 12                       Saundercock, Mr. William Henry    male
# 13                          Andersson, Mr. Anders Johan    male
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
matplotlib.pyplot.hist(titanic['Age'])
# Out:
# (array([ 72.,  78., 326., 347., 220., 136.,  75.,  42.,  10.,   3.]),
#  array([ 0.17 ,  8.153, 16.136, 24.119, 32.102, 40.085, 48.068, 56.051,
#         64.034, 72.017, 80.   ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
matplotlib.pyplot.hist(titanic['Age'], bins=(0,10,20,50))
# Out:
# (array([ 85., 162., 963.]),
#  array([ 0, 10, 20, 50]),
#  <a list of 3 Patch objects>)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
My plot has no more normal distribution. 
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.distplot(titanic['Age'], bins=range(0,100,10)),
plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
total_passengers = titanic.groupby(['Gender']).size()
total_passengers.plot.pie(x='Gender', labels=('Female','Male'),autopct='%1.1f%%', figsize=(22, 8))
plt.show()

# %%
# Method 2 - seaborn

sns.barplot(x="Gender", y="PassengerId", hue="Gender", data = titanic)

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
total_passengers = titanic.groupby(['Pclass']).size()
total_passengers.plot.pie(x='Pclass', labels=('1','2','3'),autopct='%1.1f%%', figsize=(22, 8))
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.boxplot( y=titanic["Age"] )

# %%
"""
The boxplot is a good way to represent age. 
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
There were passengers from ages from 0-60 with a few outliers above 60 but most passengers were between 22 and 37.
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
sns.distplot(titanic['Age'], bins=range(0,100,1))
plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
this shows a better detailed distribution. 
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

plt.plot(titanic['Fare'], titanic['Fare'])
plt.show()

# %%
# Method 2 - seaborn
sns.regplot(x="Age", y="Fare", data=titanic).margins(0)

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
sns.set(style="white")

# Compute the correlation matrix
corr = titanic.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Fare&Pclass have a big negative correlation, which probably means that there is a negative linear relationship.
sibsp&parch have a higher possitive correlation, which means that there were a lot of families aboard. 

"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
distribution = sns.FacetGrid(data=titanic,col='Pclass')
distribution.map(plt.hist,'Age')

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
distribution = sns.FacetGrid(data=titanic,col='Gender')
distribution.map(plt.hist,'Age')
