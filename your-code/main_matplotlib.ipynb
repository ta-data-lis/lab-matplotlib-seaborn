# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y,"g--",label='linear',linewidth=2.0)
plt.plot(x,z, "r",label='quadratic')
plt.xlim(0,50) #slice on the axis
plt.ylim(0,500)
plt.legend()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2

plot_options, (plot_1, plot_2) = plt.subplots(nrows=1, ncols=2)
plot_1.plot(x,y, "g--")
plot_2.plot(x,z, "r")
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here

plot_options, (plot_1, plot_2) = plt.subplots(nrows=1, ncols=2, figsize=(20,10))

plot_1.plot(x,y, "g--")
plot_2.plot(x,z, "r")

plot_1.set_title("Linear subplot")
plot_1.set_ylabel("This is the y label - plot 1")
plot_1.set_xlabel("This is the x label - plot 1")

plot_2.set_title("Non-linear subplot")
plot_2.set_ylabel("This is the y label - plot 2")
plot_2.set_xlabel("This is the x label - plot 2")

plot_options.suptitle("Linear vs Non Linear Plots")

plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here


x = np.linspace(-2, 2, 500)
y1 = x**2
y2 = np.exp(x)

plt.plot(x, y1, label=r'$y=x^2$')
plt.plot(x, y2, label=r'$y=e^x$')

plt.legend(loc='best')
plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
plt.legend(loc='best')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here

path = "C:/Users/migue/Documents/IRONHACK/Week 3/Labs/lab-matplotlib-seaborn/your-code/fitbit2.csv"

fitbit = pd.read_csv(path)

fitbit.head(4)
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# 0               1680  ...        0.403891    Friday           4.0
# 1               2248  ...        8.767545  Saturday           5.0
# 2               1719  ...        6.567891    Sunday           6.0
# 3               9620  ...        3.119282    Monday           0.0
#
#    Work_or_Weekend  Hours Sleep Sleep efficiency  Yesterday_sleep  \
# 0                1     6.400000        92.086331         0.000000
# 1                0     7.566667        92.464358         6.400000
# 2                0     6.450000        88.761468         7.566667
# 3                1     5.183333        88.857143         6.450000
#
#    Yesterday_sleep_efficiency  Months  Months_encoded
# 0                    0.000000     May               5
# 1                   92.086331     May               5
# 2                   92.464358     May               5
# 3                   88.761468     May               5
#
# [4 rows x 24 columns]

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
fitbit.columns

# MEDIAN STEPS BY MONTH_ENCODED
# your code here

steps_by_month = fitbit.groupby(by='Months_encoded').median()['Steps']


fig, ax = plt.subplots(figsize=(12, 4))
ax.bar(steps_by_month.index, steps_by_month.values)
ax.set_xlabel('Month')
ax.set_ylabel('Median Steps')
ax.set_title('Median Steps by Month')
plt.xticks(steps_by_month.index, ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

#plt.savefig('figures/median_steps_by_month.png')

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

steps_by_day = fitbit.groupby(by='Work_or_Weekend').median()['Steps']

fig, ax = plt.subplots(figsize=(12, 4))
ax.bar(steps_by_day.index, steps_by_day.values)
ax.set_xlabel('Day Type')
ax.set_ylabel('Median Steps')
ax.set_title('Median Steps by Day Type')
plt.xticks(steps_by_day.index, ['Weekday', 'Weekend'])

#plt.savefig('figures/median_steps_by_day_type.png')
# Out:
# ([<matplotlib.axis.XTick at 0x2bd7c47df40>,
#   <matplotlib.axis.XTick at 0x2bd7c47df10>],
#  [Text(0, 0, 'Weekday'), Text(1, 0, 'Weekend')])

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

activeness = ["Minutes Very Active", "Minutes Lightly Active", "Minutes Sedentary"]
colors = ["green", "blue", "red"]

for i,level in enumerate(activeness):
    plt.scatter(fitbit["Steps"], fitbit[level], color = colors[i])
    plt.ylabel(level)
    plt.xlabel("Steps")
    plt.title("Scatter plot of {} vs Steps".format(level))
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

path = "C:/Users/migue/Documents/IRONHACK/Week 3/Labs/lab-matplotlib-seaborn/your-code/titanic.csv"

titanic = pd.read_csv(path)

titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

numeric = titanic.select_dtypes(exclude = object)
numeric.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
# your code here


categorical = titanic.select_dtypes(include = "object")
categorical.columns
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
x = np.arange(0,100)
y = x*2
z = x**2
plt.plot(x,y,"g--",label='linear')
plt.plot(x,z, "r",label='quadratic')
plt.style.use("classic")
plt.plot(figsize = (12,6))

#plt.style.available
# Out:
# []

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

plt.hist(titanic["Age"], bins=20, edgecolor='white')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of passengers age')

plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

plt.style.use("seaborn")
plot_options, (plot_1, plot_2, plot_3) = plt.subplots(nrows=1, ncols=3, figsize=(20,10))

plot_1.hist(titanic["Age"], bins = 10)
plot_2.hist(titanic["Age"], bins = 20)
plot_3.hist(titanic["Age"], bins = 50)

plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here:

The greater the range of the bins the more uniform the histogram appears, and less detailed is the data.
"""
# Out:
# '\nyour comments here:\n\nThe greater the bins the more unifrom the histogram appears.\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
import seaborn as sns

sns.distplot(titanic["Age"])
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of passengers age')
plt.show()
# Out:
# C:\Users\migue\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

gender = titanic.groupby("Gender").agg({"PassengerId":"count"}).reset_index()
plt.figure(figsize = (5,5))
plt.bar(color = ["c","r"], x = gender["Gender"], height = gender["PassengerId"] )
plt.show()

# %%
# Method 2 - seaborn
# your code here
gender = titanic.groupby("Gender").agg({"PassengerId":"count"}).reset_index()

sns.barplot(x = gender["Gender"], y = gender["PassengerId"], palette ='viridis')

plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

pcalss = titanic.groupby("Pclass").agg({"PassengerId":"count"}).reset_index()

sns.barplot(x = pcalss["Pclass"], y = pcalss["PassengerId"], palette ='pastel')

plt.show()

# titanic.head()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

sns.boxplot(titanic["Age"])
plt.title('Summary Statistics of Passengers Age')

plt.show()
# Out:
# C:\Users\migue\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
"""
your comments here

Boxplots can be used to show the minimum, first quartile, median, third quartile
and maximum values of a dataset. They are also useful to pipoint the outliers of
the data.

"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
Most passengers were aged between 20 and 40 years old, being that the most common 
passenger age is around 28 years old.
Secondly, there seems to be an even distribution of passengers between 0 to 20 yo, and 40 to 60 years old.
Lastly, there are a few outliers present that represent passengers over 60 years and that go as far as 80 years old.
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.violinplot(titanic["Age"], color="c")
plt.show()
# Out:
# C:\Users\migue\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here:

The violin plot above, comprises the representation of the summary statistics present in a boxplot, 
plus the distribution of Age - allowing for a visual representation of the density at each point 
along the range of the x axis.
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

plt.scatter(titanic["Age"],titanic["Fare"], color = "red")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Method 2 - seaborn
# your code here


sns.regplot(data=titanic, x="Age", y="Fare")
plt.title("Linear regression plot between Age and Fare")
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here


corr=titanic.corr()

mask=np.triu(np.ones_like(corr, dtype=np.bool))

cmap = sns.diverging_palette(220,10,as_cmap=True)

sns.heatmap(corr, mask=mask, linewidths=1.5, annot=True)

plt.show()
# Out:
# C:\Users\migue\AppData\Local\Temp\ipykernel_73912\3114914713.py:6: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask=np.triu(np.ones_like(corr, dtype=np.bool))

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here

In a heatmap, the color intensity represents the magnitude of the correlation value.
As such the more correlated features are the ones with more intense colors (darker).
For this example, the more correlated features are Pclass and Fare, and Plcass and Age.
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

sns.boxplot(x = titanic["Pclass"], y = titanic["Age"])
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

gender = sns.FacetGrid(titanic, col="Gender")

gender.map(sns.distplot,"Age")
gender.add_legend()
plt.show()
# Out:
# C:\Users\migue\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\migue\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
