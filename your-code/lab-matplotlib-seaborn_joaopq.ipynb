# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
import matplotlib.pyplot as plt 

plt.plot(x,y)
plt.ylabel("y")
plt.xlabel("x")

max_y=max(x)*2
plt.axis([0,max(x),0,max_y])
plt.title("y=x^2")
plt.show()
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\joaop\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
# Method 1
plt.plot(x,z)
plt.ylabel("z")
plt.xlabel("x")

max_z=max(x)**2
plt.axis([0,max(x),0,max_z])
plt.title("y=x**2")
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2

f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x, y)
ax2.plot(x, z)
plt.axis([0,max(x),0,max_y])

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.plot(x, y)
ax1.set_title("y=x^2")

ax2.plot(x, z)
ax2.set_title("y=x**2")

plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here

#for the first plot:
plt.plot(x,y, z)
plt.ylabel("y")
plt.xlabel("x")
plt.yscale('linear')
plt.xscale('linear')
plt.title("y=x^2")
plt.show()

# %%
plt.plot(x,y, z)
plt.title("y=x**2")
plt.ylabel("y")
plt.xlabel("x")
plt.yscale('linear')
plt.xscale('log')
plt.title("y=x**2")
plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here

import pandas as pd

path="C:\\Users\\joaop\\OneDrive\\Documents\\GitHub\\lab-matplotlib-seaborn\\your-code\\Fitbit2.csv"
fitbit=pd.read_csv(path)
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
ax1=fitbit.groupby("Months_encoded")['Steps'].median()
months=['January','February','March','April','May','June','July','August','September','October','November','December']
y_pos = np.arange(12)

plt.bar(ax1.index, ax1.values)
plt.figure(figsize=(12,4))
plt.xticks(y_pos,months)
plt.savefig("figure_1")
plt.show()

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
ax2=fitbit.groupby("Work_or_Weekend")['Steps'].median()
plt.bar(ax2.index, ax2.values)
plt.xticks(y_pos,months)
plt.figure(figsize=(12,4))
plt.savefig("figure_2")
plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

columns=['Minutes Lightly Active', 'Minutes Fairly Active', 'Minutes Very Active']

for column in columns:
    plt.scatter(fitbit[column],fitbit['Steps'])

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic=pd.read_csv("C:\\Users\\joaop\\OneDrive\\Documents\\GitHub\\lab-matplotlib-seaborn\\your-code\\titanic.csv")
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(np.number)
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(exclude=np.number)
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
import seaborn as sns

plt.style.use('classic')
ax=plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
ax=plt.hist(titanic['Age'])

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
b=[10,20,50]
ax1=plt.hist(titanic['Age'],bins=b[0])
ax2=plt.hist(titanic['Age'],bins=b[1])
ax3=plt.hist(titanic['Age'],bins=b[2])

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

'''
The smaller the bin size is, the bigger the y values axis [age]. It's inversely proportional.
'''
# Out:
# "\nThe smaller the bin size is, the bigger the y values axis [age]. It's inversely proportional.\n"

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here)
ax = sns.load_dataset('titanic')
sns.distplot(titanic['Age'])
plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

ax = plt.figure(figsize=(3,3))
titanic['Gender'].value_counts().plot(kind='bar')
plt.show()

# %%
# Method 2 - seaborn
# your code here
x=['Male', 'Female']
plt.figure(figsize=(3,3))
y=titanic['Gender'].value_counts()
sns.barplot(x,y,data=titanic)
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

ax = plt.figure(figsize=(3,3))
titanic['Pclass'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
plt.boxplot(titanic['Age'],showmeans=True)

#or another way would be to put descriptive stats in as a fig text
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18fa09223c8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18f9f5bd208>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18fa0940e88>],
#  'medians': [<matplotlib.lines.Line2D at 0x18fa0999548>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18fa099fb08>],
#  'means': [<matplotlib.lines.Line2D at 0x18fa0999d88>]}

# %%
"""
your comments here
"""
''' The best plots to check distribution are either boxplots or violins, I would say.
'''
# Out:
# ' The best plots to check distribution are either boxplots or violins, I would say.\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""
''' We can see that the average is approx 30 years old and that there seem to be slightly more younger people than older.
    There are also several outliers above 60 years old (they are pointed out as small ticks)
'''
# Out:
# ' We can see that the average is approx 30 years old and that there seem to be slightly more younger people than older.\n    There are also several outliers above 60 years old (they are pointed out as small ticks)\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
ax=sns.violinplot(x=titanic["Age"],vert=False,widths=1, showmedians=True, showmeans=True, showextrema=True, bw_method=str)

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""
'''
Here we have a better visual representation of how the data is actually distributed. We can see that until circa 10y old there aren't many people.
Then the curve is steep, being most people with an age between 20 and 40 y old.
There aren't many ppl above 60y old.
'''

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

from scipy.stats import linregress

x=titanic['Fare']
y=titanic['Age']

#scatter
ax1 = titanic.plot(kind='scatter', x='Fare', y='Age', color='red', alpha=0.5, figsize=(10, 7))

#line
plt.plot(titanic.Fare, color='black', linewidth=3)

# %%
# Method 2 - seaborn
# your code here

plt.figure(figsize=(6,4))
sns.regplot(x='Age', y='Fare', data=titanic)

plt.show()

# %%
from scipy.stats import linregress
x=titanic['Fare']
y=titanic['Age']

linregress(x,y) #x and y are arrays or lists.
# Out:
# LinregressResult(slope=0.04453757017761874, intercept=28.396927011070396, rvalue=0.17135508596244756, pvalue=4.3777014565045e-10, stderr=0.007083048980983743)

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

titanic.corr()
corrMatrix=titanic.corr()

sns.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""
'''
The most correlated features seem to be Parch and SibSp with a corr=0.37
'''
# Out:
# '\nThe most correlated features seem to be Parch and SibSp with a corr=0.37\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.catplot(x="Pclass", y="Age", kind="violin",data=titanic,split=True, figsize=(3,3))

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

d_age_gend=sns.FacetGrid(col='Gender', hue='Gender',data=titanic, aspect=1,height=4)
d_age_gend=d_age_gend.map(plt.hist, 'Age')

plt.show()
