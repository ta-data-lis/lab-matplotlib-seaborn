# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
# Plot (x,y)

plt.plot(x,y)
plt.show()

# %%
# Plot (x,z)
plt.plot(x,z)
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
# Plot (x,y)

x = np.arange(0,100)
y = x*2
z = x**2

fig, ax = plt.subplots(figsize=(5,5))
ax.plot(x, y)
ax.set_title('Plot x and y')
ax.set_xlabel('xlabel')
ax.set_ylabel('ylabel')
# Out:
# Text(0, 0.5, 'ylabel')

# %%
# Method 2
# Plot (x,z)

x = np.arange(0,100)
y = x*2
z = x**2

fig, ax = plt.subplots(figsize=(5,5))
ax.plot(x, z)
ax.set_title('Plot x and z')
ax.set_xlabel('X')
ax.set_ylabel('Z')
# Out:
# Text(0, 0.5, 'Z')

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here

# Resizing the plot, adding titles and labels
x = np.arange(0,100)
y = x*2
z = x**2

fig, ax = plt.subplots(figsize=(10,10))
ax.plot(x, y)
ax.set_title('Simple plot')
ax.set_xlabel('xlabel')
ax.set_ylabel('ylabel')
# Out:
# Text(0, 0.5, 'ylabel')

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
y = x**2
#y_1 = e ** x
 
# linear
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)
plt.show()

# %%
y = x**2
#y_1 = e ** x

# log
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# your code here

# MEDIAN STEPS BY MONTH_ENCODED
#fitbit_steps_month = fitbit.groupby(["Months_encoded", ""])["Steps"].median().reset_index()
#fitbit_steps_month

ax = sns.boxplot(x="Months_encoded", y="Steps", data=fitbit)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
ax.get_figure().savefig('Months_encoded.png')

# MEDIAN STEPS BY WORK_OR_WEEKEND
ax = sns.boxplot(x="Work_or_Weekend", y="Steps", data=fitbit)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
ax.get_figure().savefig('Work_or_Weekend.png')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
plt.scatter(x = "Minutes Lightly Active", y = "Steps", data = fitbit , alpha = 0.5) 
plt.show()

# %%
variables = ["Minutes Lightly Active", "Minutes Very Active", "Minutes Sedentary"]
for variable in variables:
    plt.scatter(x = "Steps", y = variable, data = fitbit)
    plt.xlabel('variable')
    plt.ylabel('variable')
    plt.title('variable vs. variable')
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('titanic.csv')
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

# Float numbers
titanic.select_dtypes(include ='float64')
# Out:
#       Survived        Age      Fare
# 0          0.0  22.000000    7.2500
# 1          1.0  38.000000   71.2833
# 2          1.0  26.000000    7.9250
# 3          1.0  35.000000   53.1000
# 4          0.0  35.000000    8.0500
# ...        ...        ...       ...
# 1304       NaN  29.513190    8.0500
# 1305       NaN  39.000000  108.9000
# 1306       NaN  38.500000    7.2500
# 1307       NaN  29.513190    8.0500
# 1308       NaN  25.315435   22.3583
#
# [1309 rows x 3 columns]

# %%
# Integers
titanic.select_dtypes(include ='int64')
# Out:
#       PassengerId  Pclass  SibSp  Parch
# 0               1       3      1      0
# 1               2       1      1      0
# 2               3       3      0      0
# 3               4       1      1      0
# 4               5       3      0      0
# ...           ...     ...    ...    ...
# 1304         1305       3      0      0
# 1305         1306       1      0      0
# 1306         1307       3      0      0
# 1307         1308       3      0      0
# 1308         1309       3      1      1
#
# [1309 rows x 4 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include ='object')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
titanic.plot(x="Gender", y=["Age", "SibSp"], figsize=(12,6))
plt.style.use("classic")

#ax.plot(x, y, figsize=(10,10))
#ax.set_title('Simple plot')
#ax.set_xlabel('xlabel')
#ax.set_ylabel('ylabel')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
# Showing the distribution of Age
ax = sns.boxplot(x="Gender", y="Age", data=titanic)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'male'), Text(0, 0, 'female')]

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

fig, axs = plt.subplots(1, 3, figsize=(10, 5))
axs[0].hist(titanic["Age"], bins= 10)
axs[1].hist(titanic["Age"], bins= 20)
axs[2].hist(titanic["Age"], bins= 50)
# Out:
# (array([ 22.,  19.,  10.,  11.,  10.,  13.,   8.,   8.,  23.,  26.,  20.,
#          75.,  29.,  93., 109.,  43.,  72.,  68., 111.,  53.,  71.,  47.,
#          35.,  24.,  43.,  26.,  29.,  15.,  35.,  31.,  15.,  26.,   7.,
#          14.,  13.,   5.,   9.,   8.,  11.,   9.,   3.,   2.,   0.,   2.,
#           3.,   0.,   1.,   1.,   0.,   1.]),
#  array([ 0.17  ,  1.7666,  3.3632,  4.9598,  6.5564,  8.153 ,  9.7496,
#         11.3462, 12.9428, 14.5394, 16.136 , 17.7326, 19.3292, 20.9258,
#         22.5224, 24.119 , 25.7156, 27.3122, 28.9088, 30.5054, 32.102 ,
#         33.6986, 35.2952, 36.8918, 38.4884, 40.085 , 41.6816, 43.2782,
#         44.8748, 46.4714, 48.068 , 49.6646, 51.2612, 52.8578, 54.4544,
#         56.051 , 57.6476, 59.2442, 60.8408, 62.4374, 64.034 , 65.6306,
#         67.2272, 68.8238, 70.4204, 72.017 , 73.6136, 75.2102, 76.8068,
#         78.4034, 80.    ]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
When the histogram is made with more bins then the histogram is more spread. 
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
ax = sns.boxplot(x="Age", data= titanic)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
titanic['Gender'].value_counts().plot.bar()

# %%
# Method 2 - seaborn
# your code here

# %%
ax = sns.barplot(x="Gender", y="PassengerId", data= titanic)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'male'), Text(0, 0, 'female')]

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
# Method 1 - matplotlib
titanic['Pclass'].value_counts().plot.bar()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.distplot(titanic["Age"])

# %%
ax = sns.boxplot(x="Gender", y="Age", data=titanic)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'male'), Text(0, 0, 'female')]

# %%
"""
your comments here
I have used the boxplot, because it shows the average, the median and the quartiles in a good way.
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
It shows that the average age is around 30 years for both women and men.
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

sns.distplot(titanic["Age"])

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
This plot is showing more clearly the most common age and how the age is distributed.
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.bar(titanic["Age"], titanic["Fare"])
# Out:
# <BarContainer object of 1309 artists>

# %%
# Method 2 - seaborn
# your code here
ax = sns.barplot(x="Age", y= "Fare", data=titanic)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, '0.17'),
#  Text(0, 0, '0.33'),
#  Text(0, 0, '0.42'),
#  Text(0, 0, '0.67'),
#  Text(0, 0, '0.75'),
#  Text(0, 0, '0.83'),
#  Text(0, 0, '0.92'),
#  Text(0, 0, '1.0'),
#  Text(0, 0, '2.0'),
#  Text(0, 0, '3.0'),
#  Text(0, 0, '4.0'),
#  Text(0, 0, '5.0'),
#  Text(0, 0, '6.0'),
#  Text(0, 0, '7.0'),
#  Text(0, 0, '8.0'),
#  Text(0, 0, '8.26579594156'),
#  Text(0, 0, '8.614296796'),
#  Text(0, 0, '9.0'),
#  Text(0, 0, '10.0'),
#  Text(0, 0, '11.0'),
#  Text(0, 0, '11.5'),
#  Text(0, 0, '12.0'),
#  Text(0, 0, '12.671518469'),
#  Text(0, 0, '13.0'),
#  Text(0, 0, '13.5510928648'),
#  Text(0, 0, '14.0'),
#  Text(0, 0, '14.5'),
#  Text(0, 0, '14.794739623'),
#  Text(0, 0, '15.0'),
#  Text(0, 0, '16.0'),
#  Text(0, 0, '17.0'),
#  Text(0, 0, '17.9148026948'),
#  Text(0, 0, '18.0'),
#  Text(0, 0, '18.5'),
#  Text(0, 0, '19.0'),
#  Text(0, 0, '19.9786269182'),
#  Text(0, 0, '20.0'),
#  Text(0, 0, '20.0994375694'),
#  Text(0, 0, '20.5'),
#  Text(0, 0, '21.0'),
# ...

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

corr = titanic.corr()

# Generate a mask
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
           square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
The variables most correlated are the red ones and the green ones:
- SibSp and Parch
- PClass and Fare
- PClass and Age
- Survived and Fare
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
ax = sns.boxplot(x="Pclass", y="Age", data=titanic)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, '1'), Text(0, 0, '2'), Text(0, 0, '3')]

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
bins = 3
g = sns.FacetGrid(titanic, col="Age",  row="Gender")
g = g.map(plt.hist, "Gender", bins=bins, color="r")
g
